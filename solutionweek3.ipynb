# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/content/Data-cleaning-for-beginners-using-pandas (1).csv")

# %%
data.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data.tail()
# Out:
#     Index   Age     Salary  Rating       Location  Established Easy Apply
# 24     24  13.0  $44k-$99k    -1.0    New York,Ny         1987         -1
# 25     25  55.0  $44k-$99k     0.0  Australia Aus         1980       TRUE
# 26     26   NaN  $55k-$66k     NaN       India,In         1934       TRUE
# 27     27  52.0  $44k-$99k     5.4       India,In         1935         -1
# 28     28   NaN  $39k-$88k     3.4  Australia Aus         1932         -1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
data.sample(3)
# Out:
#     Index   Age     Salary  Rating     Location  Established Easy Apply
# 6       6  21.0  $44k-$99k     0.0  New York,Ny           -1         -1
# 5       5  44.0  $77k-$89k     1.4     India,In         1999       TRUE
# 16     16  19.0  $19k-$40k     4.5     India,In         1984         -1

# %%
data.shape
# Out:
# (29, 7)

# %%
data.isna().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Index', 'Age', 'Salary', 'Rating', 'Location', 'Established',
#        'Easy Apply'],
#       dtype='object')

# %%
data.columns = data.columns.str.lower().str.replace(' ','_')

# %%
data.head()
# Out:
#    index   age     salary  rating       location  established easy_apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %% [markdown]
# Age Column

# %%
med_age = data.age.mean()
print(med_age)
# Out:
# 39.04545454545455

# %%
data['age'] = data['age'].fillna(med_age)
data['age'] = data['age'].round(decimals=1)
data['age']
# Out:
# 0     44.0
# 1     66.0
# 2     39.0
# 3     64.0
# 4     25.0
# 5     44.0
# 6     21.0
# 7     44.0
# 8     35.0
# 9     22.0
# 10    55.0
# 11    44.0
# 12    39.0
# 13    25.0
# 14    66.0
# 15    44.0
# 16    19.0
# 17    39.0
# 18    35.0
# 19    32.0
# 20    39.0
# 21    35.0
# 22    19.0
# 23    39.0
# 24    13.0
# 25    55.0
# 26    39.0
# 27    52.0
# 28    39.0
# Name: age, dtype: float64

# %%
data.isna().sum()
# Out:
# index          0
# age            0
# salary         0
# rating         1
# location       0
# established    0
# easy_apply     0
# dtype: int64

# %% [markdown]
# Salary Column

# %%
data['salary'] = data['salary'].apply(lambda x:x.replace('$',''))
data['salary'] = data['salary'].apply(lambda x:x.replace('k','000'))

# %%
data['salary']
# Out:
# 0      44000-99000
# 1      55000-66000
# 2      77000-89000
# 3      44000-99000
# 4      44000-99000
# 5      77000-89000
# 6      44000-99000
# 7      44000-99000
# 8      44000-99000
# 9      44000-99000
# 10     10000-49000
# 11     10000-49000
# 12     44000-99000
# 13     44000-99000
# 14     44000-99000
# 15    88000-101000
# 16     19000-40000
# 17     44000-99000
# 18     44000-99000
# 19     44000-99000
# 20     44000-99000
# 21     44000-99000
# 22     55000-66000
# 23     44000-99000
# 24     44000-99000
# 25     44000-99000
# 26     55000-66000
# 27     44000-99000
# 28     39000-88000
# Name: salary, dtype: object

# %%
data.head()
# Out:
#    index   age       salary  rating       location  established easy_apply
# 0      0  44.0  44000-99000     5.4       India,In         1999       TRUE
# 1      1  66.0  55000-66000     3.5    New York,Ny         2002       TRUE
# 2      2  39.0  77000-89000    -1.0    New York,Ny           -1         -1
# 3      3  64.0  44000-99000     4.4       India In         1988         -1
# 4      4  25.0  44000-99000     6.4  Australia Aus         2002         -1

# %%
data['age'] = data['age'].astype(int)

# %% [markdown]
# Rating Column

# %%
rat_av = data.rating.mean()
print(rat_av)
# Out:
# 3.528571428571429

# %%
data['rating'] = data['rating'].fillna(rat_av)
data['rating'] = data['rating'].round(decimals=1)
data['rating']
# Out:
# 0     5.4
# 1     3.5
# 2    -1.0
# 3     4.4
# 4     6.4
# 5     1.4
# 6     0.0
# 7    -1.0
# 8     5.4
# 9     7.7
# 10    5.4
# 11    6.7
# 12    0.0
# 13   -1.0
# 14    4.0
# 15    3.0
# 16    4.5
# 17    5.3
# 18    6.7
# 19    3.3
# 20    5.7
# 21    5.0
# 22    7.8
# 23    2.4
# 24   -1.0
# 25    0.0
# 26    3.5
# 27    5.4
# 28    3.4
# Name: rating, dtype: float64

# %%
data.isna().sum()
# Out:
# index          0
# age            0
# salary         0
# rating         0
# location       0
# established    0
# easy_apply     0
# dtype: int64

# %%
data.replace(-1,1,inplace = True)

# %%
data.head()
# Out:
#    index  age       salary  rating       location  established easy_apply
# 0      0   44  44000-99000     5.4       India,In         1999       TRUE
# 1      1   66  55000-66000     3.5    New York,Ny         2002       TRUE
# 2      2   39  77000-89000     1.0    New York,Ny            1         -1
# 3      3   64  44000-99000     4.4       India In         1988         -1
# 4      4   25  44000-99000     6.4  Australia Aus         2002         -1

# %%
data['rating']
# Out:
# 0     5.4
# 1     3.5
# 2     1.0
# 3     4.4
# 4     6.4
# 5     1.4
# 6     0.0
# 7     1.0
# 8     5.4
# 9     7.7
# 10    5.4
# 11    6.7
# 12    0.0
# 13    1.0
# 14    4.0
# 15    3.0
# 16    4.5
# 17    5.3
# 18    6.7
# 19    3.3
# 20    5.7
# 21    5.0
# 22    7.8
# 23    2.4
# 24    1.0
# 25    0.0
# 26    3.5
# 27    5.4
# 28    3.4
# Name: rating, dtype: float64

# %% [markdown]
# Location Column

# %%
data['location']
# Out:
# 0          India,In
# 1       New York,Ny
# 2       New York,Ny
# 3          India In
# 4     Australia Aus
# 5          India,In
# 6       New York,Ny
# 7     Australia Aus
# 8       New York,Ny
# 9          India,In
# 10         India,In
# 11         India,In
# 12         India,In
# 13    Australia Aus
# 14    Australia Aus
# 15    Australia Aus
# 16         India,In
# 17      New York,Ny
# 18      New York,Ny
# 19      New York,Ny
# 20      New York,Ny
# 21      New York,Ny
# 22      New York,Ny
# 23      New York,Ny
# 24      New York,Ny
# 25    Australia Aus
# 26         India,In
# 27         India,In
# 28    Australia Aus
# Name: location, dtype: object

# %%
data['location'] = data['location'].str.replace(',In','')
data['location'] = data['location'].str.replace(',Ny','')
data['location'] = data['location'].str.replace(' In','')
data['location'] = data['location'].str.replace(' Aus','')
data['location']
# Out:
# 0         India
# 1      New York
# 2      New York
# 3         India
# 4     Australia
# 5         India
# 6      New York
# 7     Australia
# 8      New York
# 9         India
# 10        India
# 11        India
# 12        India
# 13    Australia
# 14    Australia
# 15    Australia
# 16        India
# 17     New York
# 18     New York
# 19     New York
# 20     New York
# 21     New York
# 22     New York
# 23     New York
# 24     New York
# 25    Australia
# 26        India
# 27        India
# 28    Australia
# Name: location, dtype: object

# %%
data['location'] = data['location'].astype(str)

# %% [markdown]
# Established Column

# %%
data["established"] = data["established"].replace(-1,np.nan)
data["established"].fillna('Unknown', inplace=True)

# %%
data.head()
# Out:
#    index  age       salary  rating   location  established easy_apply
# 0      0   44  44000-99000     5.4      India         1999       TRUE
# 1      1   66  55000-66000     3.5   New York         2002       TRUE
# 2      2   39  77000-89000     1.0   New York            1         -1
# 3      3   64  44000-99000     4.4      India         1988         -1
# 4      4   25  44000-99000     6.4  Australia         2002         -1

# %% [markdown]
# Easy_Apply Column

# %%
data['easy_apply'] = data['easy_apply'].replace("-1","TRUE")

# %%
data['easy_apply']
# Out:
# 0     TRUE
# 1     TRUE
# 2     TRUE
# 3     TRUE
# 4     TRUE
# 5     TRUE
# 6     TRUE
# 7     TRUE
# 8     TRUE
# 9     TRUE
# 10    TRUE
# 11    TRUE
# 12    TRUE
# 13    TRUE
# 14    TRUE
# 15    TRUE
# 16    TRUE
# 17    TRUE
# 18    TRUE
# 19    TRUE
# 20    TRUE
# 21    TRUE
# 22    TRUE
# 23    TRUE
# 24    TRUE
# 25    TRUE
# 26    TRUE
# 27    TRUE
# 28    TRUE
# Name: easy_apply, dtype: object

# %% [markdown]
# Chipotle Dataset

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/chipotle.tsv",sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# (4622, 5)

# %%
df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df['item_price'] = df['item_price'].str.replace('$', '').astype(float)
# Out:
# <ipython-input-41-10d272a7bbb9>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price'] = df['item_price'].str.replace('$', '').astype(float)

# %%
df['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# Quantity of each item

# %%
#quantity_per_item = df.groupby('item_name')['quantity'].sum()
#print(quantity_per_item)

# %%
df.item_name
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
c = df.groupby('item_name').sum()
c = c.sort_values(['quantity'], ascending = False)
c.head()
# Out:
# <ipython-input-45-b1d1ad1fdba5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c = df.groupby('item_name').sum()
#                      order_id  quantity  item_price
# item_name
# Chicken Bowl           713926       761     7342.73
# Chicken Burrito        497303       591     5575.82
# Chips and Guacamole    449959       506     2201.04
# Steak Burrito          328437       386     3851.43
# Canned Soft Drink      304753       351      438.75

# %% [markdown]
# What was the most ordered item in the choice_description column?

# %%
c = df.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending = False)
c.head(2)
# Out:
# <ipython-input-46-9e43e92d8210>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c = df.groupby('choice_description').sum()
#                     order_id  quantity  item_price
# choice_description
# [Diet Coke]           123455       159      326.71
# [Coke]                122752       143      288.79

# %% [markdown]
# How many items were ordered in total?

# %%
tot_order = df.quantity.sum()
tot_order
# Out:
# 4972

# %% [markdown]
# How much was the revenue for the period in the dataset?

# %%
rev = df['item_price'].sum()
print('Revenue was : $',rev)
# Out:
# Revenue was : $ 34500.16

# %% [markdown]
# How many orders were made in the period?

# %%
ord = df.order_id.value_counts().count()
ord
# Out:
# 1834

# %% [markdown]
# What is the average revenue amount per order?

# %%
df['rev'] = df['quantity'] * df['item_price']
d = order_grouped = df.groupby(by=['order_id']).sum()
order_grouped.mean()['rev']
# Out:
# <ipython-input-50-cd277757cd7e>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d = order_grouped = df.groupby(by=['order_id']).sum()
# 21.39423118865867

# %% [markdown]
# How many different items are sold?

# %%
df.item_name.value_counts().count()
# Out:
# 50
